# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define database and collection
db = client.mtg_cube
collection = db.cards
cube = pd.DataFrame(list(collection.find()))
cube
# Out:
#                           _id  \
# 0    604da0e9af83ceec6f7e8f7b
# 1    604da0f0af83ceec6f7e8f7c
# 2    604da0f7af83ceec6f7e8f7d
# 3    604da0fdaf83ceec6f7e8f7e
# 4    604da104af83ceec6f7e8f7f
# ..                        ...
# 508  604daeacaf83ceec6f7e9177
# 509  604daeb3af83ceec6f7e9178
# 510  604daeb9af83ceec6f7e9179
# 511  604daec0af83ceec6f7e917a
# 512  604db498af83ceec6f7e9187
#
#                                         card_image_url  \
# 0    https://c1.scryfall.com/file/scryfall-cards/la...
# 1    https://c1.scryfall.com/file/scryfall-cards/la...
# 2    https://c1.scryfall.com/file/scryfall-cards/la...
# 3    https://c1.scryfall.com/file/scryfall-cards/la...
# 4    https://c1.scryfall.com/file/scryfall-cards/la...
# ..                                                 ...
# 508  https://c1.scryfall.com/file/scryfall-cards/la...
# 509  https://c1.scryfall.com/file/scryfall-cards/la...
# 510  https://c1.scryfall.com/file/scryfall-cards/la...
# ...
